# %%
pwd
# Out:
# 'C:\\Users\\shubh\\OneDrive\\Desktop\\BANG2025'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_churn_data.csv')

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, customer_id, phone_no, gender, age, no_of_days_subscribed, multi_screen, mail_subscribed, weekly_mins_watched, minimum_daily_mins, maximum_daily_mins, weekly_max_night_mins, videos_watched, maximum_days_inactive, customer_support_calls, churn]
# Index: []

# %%
df[df.customer_id.duplicated()]
# Out:
#      year  customer_id  phone_no gender  age  no_of_days_subscribed  \
# 918  2015       530490  392-8905   Male   36                    172
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 918           no              no               323.55                 7.1
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 918               36.67                     83               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 918                    2.0                       3    0.0

# %%
df[df.customer_id.duplicated(keep = False)]
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 917  2015       530490  343-7242  Female   34                     59
# 918  2015       530490  392-8905    Male   36                    172
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 917           no             yes               199.65                 6.8
# 918           no              no               323.55                 7.1
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 917               22.63                    103               3
# 918               36.67                     83               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 917                    2.0                       1    0.0
# 918                    2.0                       3    0.0

# %%
df.duplicated(subset=['customer_id', 'gender','age'],keep = False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df[df.duplicated(subset=['customer_id'],keep = False)]
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 917  2015       530490  343-7242  Female   34                     59
# 918  2015       530490  392-8905    Male   36                    172
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 917           no             yes               199.65                 6.8
# 918           no              no               323.55                 7.1
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 917               22.63                    103               3
# 918               36.67                     83               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 917                    2.0                       1    0.0
# 918                    2.0                       3    0.0

# %%
filter_condition = df['age'] == '34'
df[filter_condition]
# Out:
# Empty DataFrame
# Columns: [year, customer_id, phone_no, gender, age, no_of_days_subscribed, multi_screen, mail_subscribed, weekly_mins_watched, minimum_daily_mins, maximum_daily_mins, weekly_max_night_mins, videos_watched, maximum_days_inactive, customer_support_calls, churn]
# Index: []

# %%
mean_age = df['age'].mean()
print(mean_age)
filter_condition = df['age'] > mean_age
df[filter_condition]
# Out:
# 38.6905
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 4     2015       101653  351-8398  Female   40                    191
# 6     2015       103051  416-1845     NaN   54                     59
# 7     2015       103225  348-7193  Female   40                     50
# ...    ...          ...       ...     ...  ...                    ...
# 1994  2015       996524  351-9604  Female   60                    141
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.shape
# Out:
# (2000, 16)

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
df.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
df.describe(include='all')
# Out:
#           year    customer_id  phone_no gender         age  \
# count   2000.0    2000.000000      2000   1976  2000.00000
# unique     NaN            NaN      2000      2         NaN
# top        NaN            NaN  409-8743   Male         NaN
# freq       NaN            NaN         1   1053         NaN
# mean    2015.0  554887.157500       NaN    NaN    38.69050
# std        0.0  261033.690318       NaN    NaN    10.20641
# min     2015.0  100198.000000       NaN    NaN    18.00000
# 25%     2015.0  328634.750000       NaN    NaN    32.00000
# 50%     2015.0  567957.500000       NaN    NaN    37.00000
# 75%     2015.0  773280.250000       NaN    NaN    44.00000
# max     2015.0  999961.000000       NaN    NaN    82.00000
#
#         no_of_days_subscribed multi_screen mail_subscribed  \
# count             2000.000000         2000            2000
# unique                    NaN            2               2
# top                       NaN           no              no
# ...

# %%
df.describe(include='object')
# Out:
#         phone_no gender multi_screen mail_subscribed
# count       2000   1976         2000            2000
# unique      2000      2            2               2
# top     409-8743   Male           no              no
# freq           1   1053         1802            1430

# %%
df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      1053
# Female     923
# Name: count, dtype: int64

# %%
df.mail_subscribed.value_counts()
# Out:
# mail_subscribed
# no     1430
# yes     570
# Name: count, dtype: int64

# %%
df.gender.unique()
# Out:
# array(['Female', nan, 'Male'], dtype=object)

# %%
df[df.gender.isnull()]
# Out:
#       year  customer_id  phone_no gender  age  no_of_days_subscribed  \
# 5     2015       101953  329-6603    NaN   31                     65
# 6     2015       103051  416-1845    NaN   54                     59
# 20    2015       107962  356-7217    NaN   57                    104
# 21    2015       108471  366-4444    NaN   32                    170
# 38    2015       113990  331-5919    NaN   48                     56
# 64    2015       121406  373-7690    NaN   36                     55
# 88    2015       131549  404-4486    NaN   39                    163
# 107   2015       141174  398-8385    NaN   39                     72
# 128   2015       152306  402-3599    NaN   26                     64
# 152   2015       164455  334-2577    NaN   46                     95
# 153   2015       164592  410-3390    NaN   41                    101
# 197   2015       185702  386-6306    NaN   28                    115
# 198   2015       185871  341-7686    NaN   36                    113
# ...

# %%
df[df.gender.isnull()].shape
# Out:
# (24, 16)

# %%
filt = (df.shape !='Male') & (df.gender != 'Female')
df[filt]
# Out:
#       year  customer_id  phone_no gender  age  no_of_days_subscribed  \
# 5     2015       101953  329-6603    NaN   31                     65
# 6     2015       103051  416-1845    NaN   54                     59
# 8     2015       103408  413-4039   Male   61                    205
# 9     2015       103676  338-5207   Male   31                     63
# 10    2015       103697  411-9554   Male   34                    114
# ...    ...          ...       ...    ...  ...                    ...
# 1993  2015       996129  401-3170   Male   36                    127
# 1996  2015       998086  383-9255   Male   45                    127
# 1997  2015       998474  353-2080    NaN   53                     94
# 1998  2015       998934  359-7788   Male   40                     94
# 1999  2015       999961  414-1496   Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male      1053
# Female     923
# NaN         24
# Name: count, dtype: int64

# %%
df['gender'].value_counts(dropna=False,normalize=True)*100
# Out:
# gender
# Male      52.65
# Female    46.15
# NaN        1.20
# Name: proportion, dtype: float64

# %%
df['churn'].value_counts(dropna=False,normalize=True)*100
# Out:
# churn
# 0.0    85.15
# 1.0    13.10
# NaN     1.75
# Name: proportion, dtype: float64

# %%
pwd
# Out:
# 'C:\\Users\\shubh\\OneDrive\\Desktop\\BANG2025'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.T
# Out:
#                             0         1         2         3         4     \
# year                        2015      2015      2015      2015      2015
# customer_id               100198    100643    100756    101595    101653
# phone_no                409-8743  340-5930  372-3750  331-4902  351-8398
# gender                    Female    Female    Female    Female    Female
# age                           36        39        65        24        40
# no_of_days_subscribed         62       149       126       131       191
# multi_screen                  no        no        no        no        no
# mail_subscribed               no        no        no       yes        no
# weekly_mins_watched       148.35    294.45      87.3     321.3     243.0
# minimum_daily_mins          12.2       7.7      11.9       9.5      10.9
# maximum_daily_mins         16.81     33.37      9.89     36.41     27.54
# weekly_max_night_mins         82        87        91       102        83
# ...

# %%
df.T
# Out:
#                             0         1         2         3         4     \
# year                        2015      2015      2015      2015      2015
# customer_id               100198    100643    100756    101595    101653
# phone_no                409-8743  340-5930  372-3750  331-4902  351-8398
# gender                    Female    Female    Female    Female    Female
# age                           36        39        65        24        40
# no_of_days_subscribed         62       149       126       131       191
# multi_screen                  no        no        no        no        no
# mail_subscribed               no        no        no       yes        no
# weekly_mins_watched       148.35    294.45      87.3     321.3     243.0
# minimum_daily_mins          12.2       7.7      11.9       9.5      10.9
# maximum_daily_mins         16.81     33.37      9.89     36.41     27.54
# weekly_max_night_mins         82        87        91       102        83
# ...

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#       age  churn  customer_id  customer_support_calls  gender mail_subscribed  \
# 0      36    0.0       100198                       1  Female              no
# 1      39    0.0       100643                       2  Female              no
# 2      65    1.0       100756                       5  Female              no
# 3      24    0.0       101595                       3  Female             yes
# 4      40    0.0       101653                       1  Female              no
# ...   ...    ...          ...                     ...     ...             ...
# 1995   54    NaN       997132                       2  Female             yes
# 1996   45    0.0       998086                       1    Male              no
# 1997   53    0.0       998474                       0     NaN              no
# 1998   40    0.0       998934                       3    Male              no
# 1999   37    1.0       999961                       1    Male              no
#
# ...

# %%
df.sort_values(by="age")
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 921   2015       531048  390-8876    Male   18                    120
# 1253  2015       678217  349-2157  Female   18                     64
# 1509  2015       779479  368-7706    Male   18                    149
# 277   2015       223234  370-7574  Female   19                    121
# 1334  2015       709479  408-3977    Male   19                      1
# ...    ...          ...       ...     ...  ...                    ...
# 280   2015       224478  419-6133    Male   76                    153
# 577   2015       364327  417-4810    Male   77                    184
# 1426  2015       742373  345-6043     NaN   79                     82
# 832   2015       490698  366-7912  Female   80                     62
# 682   2015       417761  383-4061  Female   82                    122
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df["age"]
# Out:
# 0       36
# 1       39
# 2       65
# 3       24
# 4       40
#         ..
# 1995    54
# 1996    45
# 1997    53
# 1998    40
# 1999    37
# Name: age, Length: 2000, dtype: int64

# %%
df[0:100]
# Out:
#     year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0   2015       100198  409-8743  Female   36                     62
# 1   2015       100643  340-5930  Female   39                    149
# 2   2015       100756  372-3750  Female   65                    126
# 3   2015       101595  331-4902  Female   24                    131
# 4   2015       101653  351-8398  Female   40                    191
# ..   ...          ...       ...     ...  ...                    ...
# 95  2015       136635  335-3320    Male   31                    118
# 96  2015       136931  343-4147    Male   34                     87
# 97  2015       136940  339-4317    Male   44                     95
# 98  2015       137780  342-3678    Male   35                    103
# 99  2015       137959  376-1713    Male   46                    135
#
#    multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0            no              no               148.35                12.2
# ...

# %%
df.fillna(value=5)
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080       5   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.dropna(how="any")
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1990  2015       993714  364-1969    Male   32                     61
# 1991  2015       993815  387-5891    Male   49                     50
# 1992  2015       994954  329-3222  Female   42                    119
# 1996  2015       998086  383-9255    Male   45                    127
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df['customer_id'].nunique()
# Out:
# 1999

# %%
sns.countplot(x='gender',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
gender_labels=df.gender.value_counts().index
plt.pie(df.gender.value_counts(), labels = gender_labels)
plt.show()

# %%
gender_labels_na=df.gender.value_counts(dropna=False).index
gender_labels_na
plt.pie(df['gender'].value_counts(dropna=False), labels = gender_labels_na)
plt.show()

# %%
sns.histplot(df['age'], bins = 50, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
sns.kdeplot(df['maximum_daily_mins'])
# Out:
# <Axes: xlabel='maximum_daily_mins', ylabel='Density'>

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
ages = [10,20,30,25,15]

# %%
videos_watched = df['videos_watched'].sort_values(ascending = True)
videos_watched
# Out:
# 849      0
# 419      0
# 423      0
# 452      0
# 159      0
#         ..
# 1970    15
# 1997    16
# 369     18
# 1821    18
# 1588    19
# Name: videos_watched, Length: 2000, dtype: int64

# %%
q1 = videos_watched.quantile(0.25)
q3 = videos_watched.quantile(0.75)
q2 = videos_watched.quantile(0.50)
q1,q3,q2
# Out:
# (3.0, 6.0, 4.0)

# %%
iqr = q3-q1
iqr
# Out:
# 3.0

# %%
upper_bound = 1.5*iqr + q3
lower_bound = q1- 1.5*iqr

upper_bound, lower_bound
# Out:
# (10.5, -1.5)

# %%
videos_clipped =videos_watched.clip(lower = lower_bound, upper = upper_bound)

# %%
sns.boxplot(videos_clipped)
# Out:
# <Axes: ylabel='videos_watched'>

# %%
lower_bound = videos_watched.quantile(0.04)
upper_bound = videos_watched.quantile(0.97)

# %%
lower_bound, upper_bound
# Out:
# (1.0, 10.0)

# %%
videos_clipped1 = videos_watched.clip(lower = lower_bound, upper = upper_bound)

# %%
videos_clipped1
# Out:
# 849      1
# 419      1
# 423      1
# 452      1
# 159      1
#         ..
# 1970    10
# 1997    10
# 369     10
# 1821    10
# 1588    10
# Name: videos_watched, Length: 2000, dtype: int64

# %%
sns.boxplot(videos_clipped1)
# Out:
# <Axes: ylabel='videos_watched'>
